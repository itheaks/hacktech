# %%
print("Enter the radius of circle")
# Out:
# Enter the radius of circle

# %%
import math

radius = float(input("Enter the radius of the circle: "))
area = math.pi * (radius ** 2)
print(f"The area of the circle with radius {radius} is {area:.2f}")
# Out:
# Enter the radius of the circle: 5.5
# The area of the circle with radius 5.5 is 95.03

# %%
number = int(input("Enter number: "))
if number % 3 == 0 and number % 5 == 0:
    print(f"{number} is divisible by both 3 and 5.")
else:
    print(f"{number} is not divisible by both 3 and 5.")
# Out:
# Enter number: 15
# 15 is divisible by both 3 and 5.

# %%
import math
radius = float(input("Enter the radius of the circle: "))

area = math.pi * (radius ** 2)

print(f"The area of the circle with radius {radius} is {area:.2f} square units.")

circle_data = {
    'radius': radius,
    'area': area
}

print("Circle data:")
print(circle_data)
# Out:
# Enter the radius of the circle: 6.9
# The area of the circle with radius 6.9 is 149.57 square units.
# Circle data:
# {'radius': 6.9, 'area': 149.57122623741006}
