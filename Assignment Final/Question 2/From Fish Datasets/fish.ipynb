# %%
# !kaggle datasets download -d trainingdatapro/fish-tracking-dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 403, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !pip install kaggle -q

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-ad663edf-776f-460b-801c-ec271c046949" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad663edf-776f-460b-801c-ec271c046949">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d trainingdatapro/fish-tracking-dataset
# Out:
# ...
#  99% 248M/251M [00:02<00:00, 94.9MB/s]
# 100% 251M/251M [00:02<00:00, 104MB/s]

# %%
# !unzip /content/fish-tracking-dataset.zip -d /content/
# Out:
# Archive:  /content/fish-tracking-dataset.zip
#   inflating: /content/annotations.xml
#   inflating: /content/boxes/01.png
#   inflating: /content/boxes/02.png
#   inflating: /content/boxes/03.png
#   inflating: /content/boxes/04.png
#   inflating: /content/boxes/05.png
#   inflating: /content/boxes/06.png
#   inflating: /content/boxes/07.png
#   inflating: /content/boxes/08.png
#   inflating: /content/boxes/09.png
#   inflating: /content/boxes/10.png
#   inflating: /content/boxes/11.png
#   inflating: /content/boxes/12.png
#   inflating: /content/boxes/13.png
#   inflating: /content/boxes/14.png
#   inflating: /content/boxes/15.png
#   inflating: /content/boxes/16.png
#   inflating: /content/boxes/17.png
#   inflating: /content/boxes/18.png
#   inflating: /content/boxes/19.png
#   inflating: /content/boxes/20.png
#   inflating: /content/boxes/21.png
#   inflating: /content/boxes/22.png
#   inflating: /content/boxes/23.png
#   inflating: /content/boxes/24.png
# ...

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 6.7 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/images"
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 272MB/s]
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# image 1/99 /content/images/01.jpg: 384x640 1 bird, 1 kite, 1540.4ms
# image 2/99 /content/images/02.jpg: 384x640 2 birds, 835.2ms
# image 3/99 /content/images/03.jpg: 384x640 4 birds, 2 kites, 762.1ms
# image 4/99 /content/images/04.jpg: 384x640 2 birds, 1 kite, 744.1ms
# image 5/99 /content/images/05.jpg: 384x640 1 bird, 1 kite, 768.3ms
# image 6/99 /content/images/06.jpg: 384x640 1 bird, 779.3ms
# image 7/99 /content/images/07.jpg: 384x640 3 birds, 1 teddy bear, 795.1ms
# image 8/99 /content/images/08.jpg: 384x640 6 birds, 776.2ms
# image 9/99 /content/images/09.jpg: 384x640 3 birds, 1 teddy bear, 796.5ms
# image 10/99 /content/images/10.jpg: 384x640 1 bird, 1 kite, 1 apple, 1 teddy bear, 917.2ms
# image 11/99 /content/images/11.jpg: 384x640 2 birds, 786.0ms
# ...

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.184
#     Uninstalling ultralytics-8.0.184:
#       Successfully uninstalled ultralytics-8.0.184
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/images' save=true
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults.
# This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# You may view and update settings directly in '/root/.config/Ultralytics/settings.yaml'
# ...
# 100% 6.23M/6.23M [00:00<00:00, 119MB/s]
#
# 2023-09-21 17:45:04.095722: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 17:45:05.260907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# image 1/99 /content/images/01.jpg: 384x640 3 birds, 204.7ms
# ...

# %%
from IPython import display
display.clear_output()

from ultralytics import YOLO
from IPython.display import display, Image

# %%
Image(filename='runs/detect/predict/02.jpg',height=500)

# %%
files.download("/content/runs/detect/predict2")

# %%
files.download("/content/images")

# %%
files.download("/content/runs/detect/predict2/04.jpg")

# %%
# !zip -r /content/images.zip /content/images
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/30.jpg (deflated 2%)
#   adding: content/images/11.jpg (deflated 2%)
#   adding: content/images/50.jpg (deflated 2%)
#   adding: content/images/19.jpg (deflated 2%)
#   adding: content/images/28.jpg (deflated 2%)
#   adding: content/images/10.jpg (deflated 2%)
#   adding: content/images/64.jpg (deflated 2%)
#   adding: content/images/14.jpg (deflated 2%)
#   adding: content/images/52.jpg (deflated 2%)
#   adding: content/images/91.jpg (deflated 1%)
#   adding: content/images/79.jpg (deflated 2%)
#   adding: content/images/29.jpg (deflated 2%)
#   adding: content/images/43.jpg (deflated 2%)
#   adding: content/images/73.jpg (deflated 2%)
#   adding: content/images/84.jpg (deflated 2%)
#   adding: content/images/13.jpg (deflated 2%)
#   adding: content/images/53.jpg (deflated 1%)
#   adding: content/images/34.jpg (deflated 2%)
#   adding: content/images/72.jpg (deflated 2%)
#   adding: content/images/08.jpg (deflated 2%)
# ...

# %%
# !ls /content/
# Out:
# annotations.xml  fish-tracking-dataset.zip  kaggle.json  yolov8m.pt
# boxes		 images			    runs	 yolov8n.pt
# fish.csv	 images.zip		    sample_data

# %%
from google.colab import files
files.download('/content/images.zip')

# %%
# !zip -r /content/predict2.zip /content/runs/detect/predict2
# Out:
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/30.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/11.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/50.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/19.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/28.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/10.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/64.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/14.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/52.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/91.jpg (deflated 1%)
#   adding: content/runs/detect/predict2/79.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/29.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/43.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/73.jpg (deflated 2%)
#   adding: content/runs/detect/predict2/84.jpg (deflated 2%)
# ...

# %%
# !ls /content/
# Out:
# annotations.xml  fish-tracking-dataset.zip  kaggle.json   sample_data
# boxes		 images			    predict2.zip  yolov8m.pt
# fish.csv	 images.zip		    runs	  yolov8n.pt

# %%
from google.colab import files
files.download('/content/predict2.zip')
