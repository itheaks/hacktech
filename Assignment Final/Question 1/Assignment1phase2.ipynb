# %%
print("Hello Hacktech")
# Out:
# Hello Hacktech

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.1/618.1 kB 8.5 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo detect predict model=yolov8m.pt source="/content/drive/KIST Hackathon 2023/Phase II workshop/Day 1/participants data/Amit Kumar Singh/Assignment Final/Question 1/1.webm"
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !ffmpeg -i {"/content/runs/detect/predict/1.avi"} -vcodec libx264 {"final1.avi"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !yolo detect predict model=yolov8m.pt source="/content/drive/MyDrive/timepass/2.webm"
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# video 1/1 (1/303) /content/drive/MyDrive/timepass/2.webm: 384x640 16 cars, 1 truck, 1 traffic light, 1066.1ms
# video 1/1 (2/303) /content/drive/MyDrive/timepass/2.webm: 384x640 17 cars, 2 buss, 1 truck, 1 traffic light, 929.2ms
# video 1/1 (3/303) /content/drive/MyDrive/timepass/2.webm: 384x640 14 cars, 1 bus, 1 truck, 935.9ms
# video 1/1 (4/303) /content/drive/MyDrive/timepass/2.webm: 384x640 12 cars, 1 bus, 1 truck, 1 traffic light, 995.8ms
# video 1/1 (5/303) /content/drive/MyDrive/timepass/2.webm: 384x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 1418.2ms
# video 1/1 (6/303) /content/drive/MyDrive/timepass/2.webm: 384x640 1 person, 13 cars, 1 bus, 2 trucks, 1647.7ms
# video 1/1 (7/303) /content/drive/MyDrive/timepass/2.webm: 384x640 1 person, 15 cars, 1 motorcycle, 1 bus, 1 truck, 1611.6ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict2/2.avi"} -vcodec libx264 {"final2.avi"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !yolo detect predict model=yolov8m.pt source="/content/drive/MyDrive/timepass/3.webm"
# Out:
# Ultralytics YOLOv8.0.183 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# video 1/1 (1/488) /content/drive/MyDrive/timepass/3.webm: 384x640 17 cars, 1 traffic light, 1065.2ms
# video 1/1 (2/488) /content/drive/MyDrive/timepass/3.webm: 384x640 9 cars, 1 airplane, 1 truck, 1 traffic light, 957.4ms
# video 1/1 (3/488) /content/drive/MyDrive/timepass/3.webm: 384x640 10 cars, 1 traffic light, 971.9ms
# video 1/1 (4/488) /content/drive/MyDrive/timepass/3.webm: 384x640 12 cars, 3 traffic lights, 989.1ms
# video 1/1 (5/488) /content/drive/MyDrive/timepass/3.webm: 384x640 10 cars, 1 traffic light, 1018.3ms
# video 1/1 (6/488) /content/drive/MyDrive/timepass/3.webm: 384x640 12 cars, 1 traffic light, 953.3ms
# video 1/1 (7/488) /content/drive/MyDrive/timepass/3.webm: 384x640 15 cars, 1 truck, 1077.8ms
# video 1/1 (8/488) /content/drive/MyDrive/timepass/3.webm: 384x640 13 cars, 1 traffic light, 1571.5ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict3/3.avi"} -vcodec libx264 {"final3.avi"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
